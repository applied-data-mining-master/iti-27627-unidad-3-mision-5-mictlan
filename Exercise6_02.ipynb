# %% [markdown]
# # Exercise 6.02: Activation Functions
#
# In this exercise, we will be implementing the following activation functions using the `numpy` package: `sigmoid`, `tanh`, `relu`, and `softmax`.
#
# The following steps will help you complete the exercise:

# %% [markdown]
# 1.- Import the `numpy` package as `np`

# %%
import numpy as np

# %% [markdown]
# 2.- Create a `sigmoid` function, that implements the sigmoid formula.

# %%
def sigmoid(valor):
    sigmoidV = 1/(1+np.exp(-valor))
    return sigmoidV

# %% [markdown]
# 3.- Calculate the result of sigmoid function on the value -1.
#
# Output: `0.2689414213699951`

# %%
sigmoid(-1)
# Out:
# 0.2689414213699951

# %% [markdown]
# 4.- Import the `matplotlib.pyplot` package

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 5.- Create a `numpy` array called `x` that contains values from -10 to 10 evenly spaced by an increment of 0.1, using the `np.arange()` method. Print its value.
#
# Output:
#
# ```
# array([-1.00000000e+01, -9.90000000e+00, -9.80000000e+00,
#        -9.70000000e+00, -9.60000000e+00, -9.50000000e+00,
#        -9.40000000e+00, -9.30000000e+00, -9.20000000e+00,
#        -9.10000000e+00, -9.00000000e+00, -8.90000000e+00,
#        -8.80000000e+00, -8.70000000e+00, -8.60000000e+00,
#        -8.50000000e+00, -8.40000000e+00, -8.30000000e+00,
#        -8.20000000e+00, -8.10000000e+00, -8.00000000e+00,
#        -7.90000000e+00, -7.80000000e+00, -7.70000000e+00,
#        -7.60000000e+00, -7.50000000e+00, -7.40000000e+00,
#        -7.30000000e+00, -7.20000000e+00, -7.10000000e+00,
#        -7.00000000e+00, -6.90000000e+00,
# ```

# %%
x = np.arange(-10, 10, 0.1)
x
# Out:
# array([-1.00000000e+01, -9.90000000e+00, -9.80000000e+00, -9.70000000e+00,
#        -9.60000000e+00, -9.50000000e+00, -9.40000000e+00, -9.30000000e+00,
#        -9.20000000e+00, -9.10000000e+00, -9.00000000e+00, -8.90000000e+00,
#        -8.80000000e+00, -8.70000000e+00, -8.60000000e+00, -8.50000000e+00,
#        -8.40000000e+00, -8.30000000e+00, -8.20000000e+00, -8.10000000e+00,
#        -8.00000000e+00, -7.90000000e+00, -7.80000000e+00, -7.70000000e+00,
#        -7.60000000e+00, -7.50000000e+00, -7.40000000e+00, -7.30000000e+00,
#        -7.20000000e+00, -7.10000000e+00, -7.00000000e+00, -6.90000000e+00,
#        -6.80000000e+00, -6.70000000e+00, -6.60000000e+00, -6.50000000e+00,
#        -6.40000000e+00, -6.30000000e+00, -6.20000000e+00, -6.10000000e+00,
#        -6.00000000e+00, -5.90000000e+00, -5.80000000e+00, -5.70000000e+00,
#        -5.60000000e+00, -5.50000000e+00, -5.40000000e+00, -5.30000000e+00,
# ...

# %% [markdown]
# 6.- Plot a line chart with `x` and `sigmoid(x)`
#
# Output:
#
# ![Figure 6.8](img/fig6_08.jpg)

# %%
plt.plot(x, sigmoid(x))
plt.show()

# %% [markdown]
# We can see here that the output of the `sigmoid` function ranges between 0 and 1. The slope is quite steep for values around 0.

# %% [markdown]
# 7.- Create a `tanh()` function that implements the `Tanh` formula. Then plot `x` using this function.
#
# Output:
#
# ![Figure 6.9](img/fig6_09.jpg)

# %%
def tanh(valor):
    tanhV = 2 / (1 + np.exp(-2*valor)) - 1
    return tanhV

# %%
plt.plot(x, tanh(x))
plt.show()

# %% [markdown]
# The shape of the `tanh` function is very similar to `sigmoid` but its slope is steeper for values close to 0. Remember, its range is between -1 and 1.

# %% [markdown]
# 8.- Create a `relu` function that implements the ReLU formula. Then plot using `x`.
#
# Output:
#
# ![Figure 6.10](img/fig6_10.jpg)

# %%
def relu(valor):
    reluV = np.maximum(0,valor)
    return reluV

# %%
plt.plot(x, relu(x))
plt.show()

# %% [markdown]
# The ReLU function equals 0 when values are negative, and equals the identity function, `f(x)=x`, for positive values.

# %% [markdown]
# 9.- Create a `softmax` function that implements the softmax formula.

# %%
def softmax(valores):
    softmaxV = np.exp(valores) / np.sum(np.exp(valores))
    return softmaxV

# %% [markdown]
# 10.- Calculate the output of softmax on the list of values, $[0, 1, 168, 8, 2]$.
#
# Output:
#
# ```
# array([1.09276566e-73, 2.97044505e-73, 1.00000000e+00,
#        3.25748853e-70, 8.07450679e-73])
# ```

# %%
softmax([0,1,168,8,2])
# Out:
# array([1.09276566e-73, 2.97044505e-73, 1.00000000e+00, 3.25748853e-70,
#        8.07450679e-73])

# %% [markdown]
# As expected, the item at the third position has the highest softmax probabilities as its original value was the highest.
